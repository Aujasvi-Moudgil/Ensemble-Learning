# %%
import pandas as pd

# %%
df=pd.read_excel('Folds5x2_pp.xlsx')

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# AT    9568 non-null float64
# V     9568 non-null float64
# AP    9568 non-null float64
# RH    9568 non-null float64
# PE    9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.8 KB

# %%
import seaborn as sns

sns.pairplot(df,diag_kind='kde')
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,[0,1,2,3]]
y=df.iloc[:,4]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=1)

# %%
y_train.shape
# Out:
# (7654,)

# %%
x_train.shape
# Out:
# (7654, 4)

# %%
x_tval,x_val,y_tval,y_val=train_test_split(x,y,test_size=.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_prediction=linear_model.predict(x_test)
from sklearn import metrics
import numpy as np
mse=metrics.mean_squared_error(y_test,y_prediction)
print("mean squared error",mse)
from sklearn import metrics
metrics.r2_score(y_test,y_prediction)
# Out:
# mean squared error 20.329991554850064
# 0.9321860060402446

# %%
y_prediction=linear_model.predict(x_train)
from sklearn import metrics
import numpy as np
mse=metrics.mean_squared_error(y_train,y_prediction)
print("mean squared error",mse)
from sklearn import metrics
metrics.r2_score(y_train,y_prediction)
# Out:
# mean squared error 20.88157603230847
# 0.9277745463518707

# %%
y_prediction=linear_model.predict(x_val)
from sklearn import metrics
import numpy as np
mse=metrics.mean_squared_error(y_val,y_prediction)
print("mean squared error",mse)
from sklearn import metrics
metrics.r2_score(y_val,y_prediction)
# Out:
# mean squared error 20.7778827130908
# 0.9294871459131931

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,[0,1,2,3]]
y=df.iloc[:,4]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=1)
x_tval,x_val,y_tval,y_val=train_test_split(x,y,test_size=.3,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_prediction=linear_model.predict(x_train)
from sklearn import metrics
import numpy as np

from sklearn import metrics
metrics.r2_score(y_train,y_prediction)
# Out:
# 0.9277745463518707

# %%
y_prediction=linear_model.predict(x_val)
from sklearn import metrics
import numpy as np
mse=metrics.mean_squared_error(y_val,y_prediction)
print("mean squared error",mse)
from sklearn import metrics
metrics.r2_score(y_val,y_prediction)
# Out:
# mean squared error 20.7778827130908
# 0.9294871459131931
